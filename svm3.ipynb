# %% [markdown]
# # SVMs with Transformed `clicks`
# Yeo-Johnson transformation has been applied to `clicks` to give it a more normal distribution.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load in Data and Split Training and Testing Data

# %%
# Read in the cleaned CSV file with transformed 'clicks'
df = pd.read_csv('svm_project_data.csv')

# Downsampling: Randomly sample 1000 instances from both class 0 and class 1
# Setting random_state ensures reproducibility for everyone in the group
df_class_0 = df[df['conversions'] == 0].sample(n=10000, random_state=42)
df_class_1 = df[df['conversions'] == 1].sample(n=10000, random_state=42)

# Concatenate the sampled data and shuffle (frac=1 returns 100% of the rows in random order)
df_subset = pd.concat([df_class_0, df_class_1]).sample(frac=1, random_state=42).reset_index(drop=True)


# Separate independent and dependent variables
x = df.iloc[:, :-1]
y = df.loc[:, ['conversions']]

# Split the training and testing data with a ratio of 80:20
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Combine the balanced classes
df_balanced = pd.concat([df_class_0, df_class_1])

# Convert dependent variable to 1D array to work with sklearn
y_train = y_train.to_numpy().ravel()
y_test = y_test.to_numpy().ravel()

# %% [markdown]
# ### 3. Create a SVM classifier with linear kernel
# Random search is used to optimize the hyperparameters since it takes significantly less time to run than grid search.

# %%
# Create SVM classifier with RBF kernel
model = svm.SVC(kernel='linear')

# Specify hyperparameters to tune
param_dict = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]}

# Perform hyperparameter tuning with random search
random_search = RandomizedSearchCV(model, param_distributions=param_dict, n_iter=10, cv=5, verbose=2, n_jobs=-1)
random_search.fit(x_train, y_train)

# Get best model
best_model = random_search.best_estimator_

# Make predictions on testing data with best hyperparameters
y_pred = best_model.predict(x_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END .................................C=10, gamma=0.0001; total time= 1.6min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.7min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.7min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.7min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.7min
# [CV] END ..................................C=100, gamma=0.01; total time= 4.3min
# [CV] END ..................................C=100, gamma=0.01; total time= 4.7min
# [CV] END ..................................C=100, gamma=0.01; total time= 4.8min
# [CV] END ...................................C=0.1, gamma=0.1; total time=  24.2s
# /Users/andreanaargyres/Documents/GitHub/ECS171-Group10/.venv/lib/python3.13/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ...................................C=0.1, gamma=0.1; total time=  27.8s
# [CV] END .....................................C=100, gamma=1; total time= 4.1min
# [CV] END .....................................C=100, gamma=1; total time= 4.6min
# [CV] END ...................................C=0.1, gamma=0.1; total time=  34.8s
# [CV] END ...................................C=0.1, gamma=0.1; total time=  33.1s
# [CV] END .....................................C=100, gamma=1; total time= 4.7min
# [CV] END ..................................C=100, gamma=0.01; total time= 4.8min
# [CV] END ..................................C=100, gamma=0.01; total time= 5.2min
# [CV] END ...................................C=0.1, gamma=0.1; total time=  36.2s
# [CV] END .....................................C=100, gamma=1; total time= 4.7min
# [CV] END .....................................C=100, gamma=1; total time= 5.3min
# [CV] END ................................C=100, gamma=0.0001; total time= 4.4min
# [CV] END ................................C=1000, gamma=0.001; total time= 5.2min
# [CV] END ................................C=100, gamma=0.0001; total time= 4.0min
# [CV] END ................................C=1000, gamma=0.001; total time= 6.3min
# [CV] END ..................................C=0.1, gamma=0.01; total time=  26.1s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  28.9s
# [CV] END ................................C=1000, gamma=0.001; total time= 7.2min
# [CV] END ................................C=1000, gamma=0.001; total time= 7.5min
# [CV] END ..................................C=0.1, gamma=0.01; total time=  38.0s
# [CV] END ................................C=100, gamma=0.0001; total time= 4.2min
# [CV] END ..................................C=0.1, gamma=0.01; total time=  38.1s
# [CV] END ..................................C=0.1, gamma=0.01; total time=  39.0s
# [CV] END ................................C=1000, gamma=0.001; total time= 9.3min
# [CV] END ................................C=100, gamma=0.0001; total time= 4.3min
# [CV] END ..................................C=1, gamma=0.0001; total time=  33.3s
# [CV] END ..................................C=1, gamma=0.0001; total time=  35.8s
# [CV] END ................................C=100, gamma=0.0001; total time= 4.8min
# [CV] END ..................................C=1, gamma=0.0001; total time=  32.7s
# [CV] END ..................................C=1, gamma=0.0001; total time=  33.8s
# [CV] END ..................................C=1, gamma=0.0001; total time=  30.7s
# [CV] END ..................................C=1000, gamma=0.1; total time= 5.3min
# [CV] END ..................................C=1000, gamma=0.1; total time= 6.3min
# [CV] END ..................................C=1000, gamma=0.1; total time= 7.3min
# [CV] END ..................................C=1000, gamma=0.1; total time= 7.8min
# [CV] END ....................................C=1000, gamma=1; total time= 5.1min
# [CV] END ..................................C=1000, gamma=0.1; total time= 8.7min
# [CV] END ....................................C=1000, gamma=1; total time= 7.1min
# [CV] END ....................................C=1000, gamma=1; total time= 8.1min
# [CV] END ....................................C=1000, gamma=1; total time= 5.5min
# [CV] END ....................................C=1000, gamma=1; total time= 4.8min

# %%
# Display best hyperparameters
print(f'Best Hyperparameters: {random_search.best_params_}')

# Display metrics on the best linear model
class_report = classification_report(y_test, y_pred, target_names=['Not Converted (0)', 'Converted (1)'])
print(class_report)

# Create confusion matrix for the testing set
matrix_labels = ['Not Converted (0)', 'Converted (1)']
matrix = confusion_matrix(y_test, y_pred)
ax = plt.subplot()
sns.heatmap(matrix, annot=True, fmt="g", ax=ax, cmap="flare",
            linewidths=0.5, linecolor="black", square=True)
ax.set_title("Testing Set Confusion Matrix for SVM with Linear Kernel", fontsize=20)
ax.set_xlabel("Predicted Labels", fontsize=12)
ax.set_ylabel("True Labels", fontsize=12)
ax.xaxis.set_ticklabels(matrix_labels, fontsize=12)
ax.yaxis.set_ticklabels(matrix_labels, fontsize=12)
plt.show()
# Out:
# Best Hyperparameters: {'gamma': 0.01, 'C': 100}
#                    precision    recall  f1-score   support
#
# Not Converted (0)       0.87      0.84      0.86      2006
#     Converted (1)       0.98      0.99      0.98     17994
#
#          accuracy                           0.97     20000
#         macro avg       0.93      0.91      0.92     20000
#      weighted avg       0.97      0.97      0.97     20000

# %% [markdown]
# ### 4. Create a SVM classifier with RBF kernel
# Random search is used to optimize the hyperparameters since it takes significantly less time to run than grid search.

# %%
# Create SVM classifier with RBF kernel
rbf_model = svm.SVC(kernel='rbf')

# Specify hyperparameters to tune
param_dict = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]}

# Perform hyperparameter tuning with random search
random_search_rbf = RandomizedSearchCV(rbf_model, param_distributions=param_dict, n_iter=10, cv=5, verbose=2, n_jobs=-1)
random_search_rbf.fit(x_train, y_train)

# Get best model
best_rbf_model = random_search_rbf.best_estimator_

# Make predictions on testing data with best hyperparameters
y_pred_rbf = best_rbf_model.predict(x_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ................................C=100, gamma=0.0001; total time= 1.2min
# [CV] END ................................C=100, gamma=0.0001; total time= 1.2min
# [CV] END ................................C=100, gamma=0.0001; total time= 1.2min
# [CV] END ................................C=100, gamma=0.0001; total time= 1.3min
# [CV] END ................................C=100, gamma=0.0001; total time= 1.3min
# [CV] END ................................C=1000, gamma=0.001; total time= 1.1min
# [CV] END ................................C=1000, gamma=0.001; total time= 1.1min
# [CV] END ................................C=1000, gamma=0.001; total time= 1.1min
# [CV] END ................................C=1000, gamma=0.001; total time= 1.0min
# [CV] END ................................C=1000, gamma=0.001; total time= 1.0min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.7min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.6min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.7min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.7min
# [CV] END ....................................C=1, gamma=0.01; total time= 1.5min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.7min
# [CV] END ....................................C=1, gamma=0.01; total time= 1.5min
# [CV] END ....................................C=1, gamma=0.01; total time= 1.5min
# [CV] END ....................................C=1, gamma=0.01; total time= 1.5min
# [CV] END ....................................C=1, gamma=0.01; total time= 1.5min
# [CV] END ..................................C=0.1, gamma=0.01; total time= 1.6min
# [CV] END ..................................C=0.1, gamma=0.01; total time= 1.7min
# [CV] END ..................................C=0.1, gamma=0.01; total time= 1.7min
# [CV] END ..................................C=0.1, gamma=0.01; total time= 1.7min
# [CV] END ..................................C=0.1, gamma=0.01; total time= 1.8min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.6min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.6min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.5min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.5min
# [CV] END .................................C=100, gamma=0.001; total time=  46.5s
# [CV] END .................................C=100, gamma=0.001; total time=  48.2s
# [CV] END .................................C=10, gamma=0.0001; total time= 1.5min
# [CV] END .................................C=100, gamma=0.001; total time=  47.9s
# [CV] END .................................C=100, gamma=0.001; total time=  44.8s
# [CV] END .................................C=100, gamma=0.001; total time=  45.8s
# [CV] END ..................................C=100, gamma=0.01; total time= 1.4min
# [CV] END ..................................C=100, gamma=0.01; total time= 1.6min
# [CV] END ..................................C=100, gamma=0.01; total time= 1.5min
# [CV] END ..................................C=100, gamma=0.01; total time= 1.3min
# [CV] END ..................................C=100, gamma=0.01; total time= 1.4min
# [CV] END .................................C=1000, gamma=0.01; total time= 3.3min
# [CV] END ....................................C=1000, gamma=1; total time=20.3min
# [CV] END ....................................C=1000, gamma=1; total time=20.3min
# [CV] END ....................................C=1000, gamma=1; total time=20.3min
# [CV] END .................................C=1000, gamma=0.01; total time= 3.2min
# [CV] END .................................C=1000, gamma=0.01; total time= 2.9min
# [CV] END ....................................C=1000, gamma=1; total time=19.8min
# [CV] END ....................................C=1000, gamma=1; total time=19.8min
# [CV] END .................................C=1000, gamma=0.01; total time= 2.0min
# [CV] END .................................C=1000, gamma=0.01; total time= 1.9min

# %%
# Display best hyperparameters
print(f'Best Hyperparameters: {random_search_rbf.best_params_}')

# Display metrics on the best RBF model
class_report_rbf = classification_report(y_test, y_pred_rbf, target_names=['Not Converted (0)', 'Converted (1)'])
print(class_report_rbf)

# Create confusion matrix for the testing set
matrix_labels = ['Not Converted (0)', 'Converted (1)']
rbf_matrix = confusion_matrix(y_test, y_pred_rbf)
ax = plt.subplot()
sns.heatmap(rbf_matrix, annot=True, fmt="g", ax=ax, cmap="flare",
            linewidths=0.5, linecolor="black", square=True)
ax.set_title("Testing Set Confusion Matrix for SVM with RBF Kernel", fontsize=20)
ax.set_xlabel("Predicted Labels", fontsize=12)
ax.set_ylabel("True Labels", fontsize=12)
ax.xaxis.set_ticklabels(matrix_labels, fontsize=12)
ax.yaxis.set_ticklabels(matrix_labels, fontsize=12)
plt.show()
# Out:
# Best Hyperparameters: {'gamma': 0.01, 'C': 1000}
#                    precision    recall  f1-score   support
#
# Not Converted (0)       0.91      0.88      0.89      2006
#     Converted (1)       0.99      0.99      0.99     17994
#
#          accuracy                           0.98     20000
#         macro avg       0.95      0.93      0.94     20000
#      weighted avg       0.98      0.98      0.98     20000
